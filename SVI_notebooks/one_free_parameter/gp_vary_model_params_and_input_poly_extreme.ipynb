# %% [markdown]
# Using a subsample of r in the model eleviated some problems, like initialization errors of the gp when using (0,0,0).
# Also fixed the memory error during gp calculation.
#
# How to sample the other parameters in the model?
#
# Finding interpolation rutine implemented in jax.
# Current one only supports linear interpolation, while cubic would be prefered.
# Maybe use jax_cosmo.scipy.interpolate. Suggestions?
#
# Memory problems when using a 200x200 image. 100x100 works for now.
# Currently testing our older implementation on bigger grids, current maximum was 500x500 grid with a runtime of 12-20 minutes. testing of larger grids still in progress.
# This was with only one free parameter.

# %% [markdown]
#     #sigma_p = numpyro.sample("sigma_p", dist.HalfNormal(1.))
#     #length_scale_p = numpyro.sample("length_scale_p", dist.HalfNormal(0.1))
#
#     #add log error in observed image do same in model log image sample log error obver gaussian distribution done
#     # add plot loss over svi steps done
#     # add predictive
#     # add deterministic
#
#
#     # do longer runs to see if std converges and larger noise try up to 50%
#     # add deterministic to sb and calculate mean/std
#     # try different inital p function
#     # observe_image - mean predition / std_pred instead of residual

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import jax.numpy as jnp
from jax import grad, vmap
from matplotlib.colors import LogNorm
import jax
import random

from JAX_Deprojection import surface_brightness as sb
from JAX_Deprojection import density_distribution as den
import jax
import numpyro
import numpyro.distributions as dist
from tinygp import kernels, GaussianProcess
from numpyro.infer.autoguide import AutoNormal
from numpyro.infer import SVI, Trace_ELBO, Predictive
from numpyro.optim import Adam
from jax.scipy.interpolate import RegularGridInterpolator

# %%
'''
s_def = 1. 

e_k_def = 0.0 
e_d_def = 0.0

p_a_def = 0.00160907
p_b_def = -0.02122767
p_c_def = 0.07711992
p_d_def = 0.54249868

q_a_def = 0.0
q_b_def = 0.0
q_c_def = 0.0
q_d_def = 0.6

a_def = 2.
b_def = 4.
rho0_def = 0.001
i_def = 0.
phi_def = 0.
theta_def = 0.

size = 100
extent = 5
extents = [-extent, extent,-extent, extent]
'''
# Out:
# '\ns_def = 1. \n\ne_k_def = 0.0 \ne_d_def = 0.0\n\np_a_def = 0.00160907\np_b_def = -0.02122767\np_c_def = 0.07711992\np_d_def = 0.54249868\n\nq_a_def = 0.0\nq_b_def = 0.0\nq_c_def = 0.0\nq_d_def = 0.6\n\na_def = 2.\nb_def = 4.\nrho0_def = 0.001\ni_def = 0.\nphi_def = 0.\ntheta_def = 0.\n\nsize = 100\nextent = 5\nextents = [-extent, extent,-extent, extent]\n'

# %%
def create_dummy_image(p_a_def,p_b_def,p_c_def,p_d_def,error_fraction):
    s_def = 1. 

    e_k_def = 0.0 
    e_d_def = 0.0

    q_a_def = 0.0
    q_b_def = 0.0
    q_c_def = 0.0
    q_d_def = 0.6

    a_def = 2.
    b_def = 4.
    rho0_def = 1.
    i_def = 0.
    phi_def = 0.
    theta_def = 0.

    size = 100
    extent = 5
    extents = [-extent, extent,-extent, extent]



    sb_1= sb.Surface_brightness()
    sb_1.generate(size,extent, e_k_def, e_d_def, p_a_def, p_b_def, p_c_def, p_d_def, q_a_def, q_b_def, q_c_def, q_d_def, rho0_def, s_def, a_def, b_def, i_def, phi_def, theta_def)
    plt.imshow(sb_1.data.T, norm=colors.LogNorm(vmin=sb_1.data.min(), vmax=sb_1.data.max()), origin='lower',extent = extents)
    plt.colorbar()

    key = jax.random.PRNGKey(42)
    noise = jax.random.normal(key, shape=sb_1.data.shape) * (error_fraction * sb_1.data)
    noisy_data = jnp.clip(sb_1.data + noise, 1e-6, None)


    return noisy_data, extents,size
#0.00914918 -0.12086247  0.44761072  0.07762238
p_a_def = 0.00914918
p_b_def = -0.12086247
p_c_def = 0.44761072
p_d_def = 0.07762238

noisy_data, extents, size = create_dummy_image(p_a_def,p_b_def,p_c_def,p_d_def,0.2)


#noisy_data = np.zeros_like(noisy_data)

# %%
plt.imshow(noisy_data.T, norm=LogNorm(), origin='lower',extent = extents)
plt.colorbar()

# %%
#np.min(sb_1.data+noise)

# %%
#sb_1.x_coord

# %%
#try rho funcction that we use in package

def rho(x, y, z, e, p, q, rho0, s, a, b):
    #eps = 1e-12
    #r = (jnp.abs(x)**2 + jnp.abs(y)**2 + jnp.abs(z)**2)**0.5
    m = ((jnp.abs(x)**(2 - e) + (jnp.abs(y) / p)**(2 - e) + (jnp.abs(z) / q)**(2 - e)))**(1 / (2 - e)) 
    #m = jnp.maximum(m, eps)
    den = rho0 / ((m / s)**a * (1 + (m / s))**(b - a))
    return den / (p * q)

# %%
from JAX_Deprojection import utils

numpyro.enable_validation(is_validate=True)

# create r array smallest smaller than grid biggest bigger with ~100 points
def model(rho_x, rho_y, rho_z, r, sigma_obs=None):
    #eps = 1e-12

    r_gp = jnp.linspace(jnp.min(r)-0.05,jnp.max(r)+0.5,1000)

    # Sample the parameters of the linear mean function
    k_low = numpyro.sample("k_low", dist.Uniform(-10.,10)) #-0.11
    k_high= numpyro.sample("k_high", dist.Uniform(-10.,10))
    d = numpyro.sample("d", dist.Uniform(-10.,50)) #0.5
    r_turn = numpyro.sample("r_turn", dist.Uniform(0.,10)) 
    #smoothness = numpyro.sample("smoothness", dist.Uniform(0.001,10))

    # Define the linear mean function
    def sigmoid_function(r):
        return 1. / (1. + jnp.exp(-(r-r_turn)))

    def mean_function(r):
        return k_low*r*(1-sigmoid_function(r)) + k_high*r*sigmoid_function(r) + d
    
    #h1 = numpyro.sample("h1", dist.Uniform(-1.,1)) 
    #h2= numpyro.sample("h2", dist.Uniform(-1.,1))
    #h3 = numpyro.sample("h3", dist.Uniform(-1.,1)) 
    

    

    #def mean_function(r):
        #return h1 + h2*r + h3*r**2
    
    #r = jnp.maximum(r,eps)

    #m = numpyro.sample("m", dist.Uniform(-10.,10))
    
    # GP parameters for p(r)
    sigma_p = numpyro.sample("sigma_p", dist.TruncatedNormal(0.,1. ,low = 0.01,high=3.))
    length_scale_p = numpyro.sample("length_scale_p", dist.Uniform(1.,5.)) 
    #sigma_p = 1.0
    #length_scale_p = 0.5 
    kernel_p = sigma_p**2 * kernels.ExpSquared(length_scale_p)
    gp_p = GaussianProcess(kernel_p, r_gp, diag=1e-5, mean=mean_function)  #linear_mean_function
    p_not_transformed = numpyro.sample("p_not_transformed", gp_p.numpyro_dist())
    #p = numpyro.deterministic("p",jax.nn.sigmoid(p_not_transformed))
    p= numpyro.deterministic("p", jnp.clip(p_not_transformed, min = 0.00001, max = 1.))
    interpolator = RegularGridInterpolator((r_gp,), p, method="linear", bounds_error=False, fill_value=None)

    # Interpolate the values
    p_final = interpolator(r)

    # Constant parameters
    q = 0.6
    e = 0.0
    rho0 = 1.0
    s = 1.0
    a = 2.0
    b = 4.0


    # Compute the density
    density = utils.rho(rho_x, rho_y, rho_z, e, e, 0., 0., 0., p_final, 0., 0., 0., q, rho0, s, a, b, 0., 0., 0.)

    sb = numpyro.deterministic("sb", jnp.sum(density, axis = 2))

    # Observation model
    numpyro.sample("sigma_obs", dist.Normal(sb, 0.2 * sb), obs=sigma_obs)




# write email to sudeshna

#works until ~2500 steps
#change ab to 2 and 4

# skip gp do sample p use restricted prior, uniform 0 and 1, dont need deterministic
# autodelta guide just best solution without uncertainty
# less steps
#sample predictive and see if model performs correctly by inputing params by hand


# tweak stepsize
# simplified model for linear p
# try fixating a and b and see what happens
# with clip we dont need a sigmoid transform

# test run one with sigmoid one with clip
# mean function does not seem to have big impact

# %%
def runsvi(adam,elbo,noisy_data,steps,rho_x,rho_y,rho_z,r):# Use AutoGuide for variational inference
    guide = AutoNormal(model)

    # Optimizer and inference
    optim = Adam(adam)
    svi = SVI(model, guide, optim, Trace_ELBO(elbo))
    key = jax.random.PRNGKey(42)

    results = svi.run(key, steps, rho_x,rho_y,rho_z,r, sigma_obs=noisy_data)

    return results, guide 

#maybe use svi step instead of svi run to use dynamic step number and prevent loss from going to infinity

# %%
#steps = 500
extent = extents[1]

x,y = jnp.meshgrid(jnp.linspace(-extent,extent,size),jnp.linspace(-extent,extent,size),indexing='ij')

x = x.flatten()
y = y.flatten()
grid_size = jnp.astype(jnp.sqrt(len(x)),jnp.int32)

rho_x,rho_y,rho_z = utils.create_grid(grid_size,jnp.max(x))
r = jnp.sqrt(rho_x**2 + rho_y**2 + rho_z**2)

r_gp = jnp.linspace(jnp.min(r)-0.05,jnp.max(r)+0.5,1000)

#results, guide = runsvi(0.1,1,noisy_data,steps,rho_x,rho_y,rho_z,r)

# %%
def p(r,p_a,p_b,p_c,p_d):
    p = p_a * r**3 + p_b * r**2 + p_c * r + p_d
    return p

def plot_p_sample(adam,elbo,steps,p_mean,p_std,r_gp,p_a_def,p_b_def,p_c_def,p_d_def):
    
    p_obs = p(r_gp,p_a_def,p_b_def,p_c_def,p_d_def)


    # Plot p(r)
    plt.figure(figsize=(8, 6))
    plt.plot(r_gp, p_mean, label="Predicted p(r)")
    plt.plot(r_gp,p_obs, label="True p(r)")
    #plt.errorbar(r_gp,p_mean, yerr = p_std,ecolor ="blue")
    plt.fill_between(r_gp, p_mean - p_std, p_mean + p_std, alpha=0.2, label="Uncertainty")
    plt.xlabel("Radial distance (r)")
    plt.ylabel("p(r)")
    plt.title("Predicted p as a function of radial distance: Stepsize {}, Elbo {}, Steps {}".format(adam,elbo,steps))
    plt.legend()
    plt.grid(True)
    plt.ylim(0,1)
    plt.show()

def plot_comparison(adam,elbo,steps,noisy_data,p_mean,sb_mean,sb_std,p_a_def,p_b_def,p_c_def,p_d_def):


    interpolator = RegularGridInterpolator((r_gp,), p_mean, method="linear", bounds_error=False, fill_value=None)
    # Interpolate the values

    sorting_indices = jnp.argsort(r)  # Get indices that sort r_obs
    r_sorted = r[sorting_indices]  # Sort r_obs

    #p_sampled_full = interpolator(r)

    p_sampled_full_sorted = interpolator(r_sorted)
    p_obs = p(r_sorted,p_a_def,p_b_def,p_c_def,p_d_def)


    # Set up the figure and subplots
    fig, axes = plt.subplots(4, figsize=(8,16))


    #key = jax.random.PRNGKey(42)

    # Plot data in each subplot


    ax1 = axes[0]
    ax2 = axes[1]
    ax3 = axes[2]
    ax4 = axes[3]

    img1 = ax1.imshow(noisy_data.T, norm=colors.LogNorm(vmin=noisy_data.min(), vmax=noisy_data.max()), origin='lower',extent = extents)
    fig.colorbar(img1, ax=ax1, label='Color Scale')
    ax1.set_title("True p_a: "+str(p_a_def)+" True p_b: "+str(p_b_def)+" True p_c: "+str(p_c_def)+" True p_d: "+str(p_d_def))

    img2 = ax2.imshow(sb_mean.T, norm=colors.LogNorm(vmin=sb_mean.min(), vmax=sb_mean.max()), origin='lower',extent = extents)
    fig.colorbar(img2, ax=ax2, label='Color Scale')
    ax2.set_title("With predicted p using model parameters: Stepsize {}, Elbo {}, Steps {}".format(adam,elbo,steps))

    residual = (noisy_data - sb_mean)/sb_mean
    img3 = ax3.imshow(residual.T, origin='lower',extent = extents)
    fig.colorbar(img3, ax=ax3, label='Color Scale')
    score = utils.ssd_score(noisy_data,sb_mean,sb_mean)
    ax3.set_title("Residual Score: "+str(score))

    ax4.plot(r_sorted, p_obs, label="True function of p(r)")
    ax4.plot(r_sorted, p_sampled_full_sorted, label="Predicted function of p(r)")

    ax4.legend()
    ax4.set_xlabel('r')
    ax4.set_ylabel('p(r)')
    ax4.grid(True)
    ax4.set_ylim([0,1])


    # Adjust layout to avoid overlap
    plt.tight_layout()
    plt.show()

# %%
adam_params = [0.2]
elbo_params = [10]
steps_param = [300]

for i in range(len(adam_params)):
    for j in range(len(elbo_params)):
        for k in range(len(steps_param)):
            print(adam_params[i],elbo_params[j],steps_param[k])
            results, guide = runsvi(adam_params[i],elbo_params[j],noisy_data,steps_param[k],rho_x,rho_y,rho_z,r)

            key = jax.random.PRNGKey(42)

            predictive = Predictive(guide, params=results.params, num_samples=1000)
            posterior_samples = predictive(key,rho_x,rho_y,rho_z,r)

            predictive = Predictive(model, posterior_samples, params=results.params, num_samples=1000)
            posterior_predictive_samples = predictive(key,rho_x,rho_y,rho_z,r)


            p_mean = posterior_predictive_samples['p'].mean(axis=0)
            p_std = posterior_predictive_samples['p'].std(axis=0)

            sb_mean = posterior_predictive_samples['sb'].mean(axis=0)
            sb_std = posterior_predictive_samples['sb'].std(axis=0)

            plot_p_sample(adam_params[i],elbo_params[j],steps_param[k],p_mean,p_std,r_gp,p_a_def,p_b_def,p_c_def,p_d_def)

            plot_comparison(adam_params[i],elbo_params[j],steps_param[k],noisy_data,p_mean,sb_mean,sb_std,p_a_def,p_b_def,p_c_def,p_d_def)
# Out:
# 0.2 10 300
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 9
#       7 for k in range(len(steps_param)):
#       8     print(adam_params[i],elbo_params[j],steps_param[k])
# ----> 9     results, guide = runsvi(adam_params[i],elbo_params[j],noisy_data,steps_param[k],rho_x,rho_y,rho_z,r)
#      11     key = jax.random.PRNGKey(42)
#      13     predictive = Predictive(guide, params=results.params, num_samples=1000)
#
# Cell In[65], line 9, in runsvi(adam, elbo, noisy_data, steps, rho_x, rho_y, rho_z, r)
#       6 svi = SVI(model, guide, optim, Trace_ELBO(elbo))
#       7 key = jax.random.PRNGKey(42)
# ----> 9 results = svi.run(key, steps, rho_x,rho_y,rho_z,r, sigma_obs=noisy_data)
#      11 return results, guide
#
# File z:\anaconda3\envs\new_env\Lib\site-packages\numpyro\infer\svi.py:401, in SVI.run(self, rng_key, num_steps, progress_bar, stable_update, forward_mode_differentiation, init_state, init_params, *args, **kwargs)
#     398     return svi_state, loss
#     400 if init_state is None:
# --> 401     svi_state = self.init(rng_key, *args, init_params=init_params, **kwargs)
#     402 else:
#     403     svi_state = init_state
#
# File z:\anaconda3\envs\new_env\Lib\site-packages\numpyro\infer\svi.py:184, in SVI.init(self, rng_key, init_params, *args, **kwargs)
#     182 if init_params is not None:
#     183     guide_init = substitute(guide_init, init_params)
# --> 184 guide_trace = trace(guide_init).get_trace(*args, **kwargs, **self.static_kwargs)
#     185 init_guide_params = {
#     186     name: site["value"]
#     187     for name, site in guide_trace.items()
#     188     if site["type"] == "param"
#     189 }
#     190 if init_params is not None:
#
# File z:\anaconda3\envs\new_env\Lib\site-packages\numpyro\handlers.py:186, in trace.get_trace(self, *args, **kwargs)
#     178 def get_trace(self, *args, **kwargs):
#     179     """
#     180     Run the wrapped callable and return the recorded trace.
#     181
#    (...)
#     184     :return: `OrderedDict` containing the execution trace.
#     185     """
# --> 186     self(*args, **kwargs)
#     187     return self.trace
#
# File z:\anaconda3\envs\new_env\Lib\site-packages\numpyro\primitives.py:105, in Messenger.__call__(self, *args, **kwargs)
#     103     return self
#     104 with self:
# --> 105     return self.fn(*args, **kwargs)
#
# File z:\anaconda3\envs\new_env\Lib\site-packages\numpyro\primitives.py:105, in Messenger.__call__(self, *args, **kwargs)
#     103     return self
#     104 with self:
# --> 105     return self.fn(*args, **kwargs)
#
# File z:\anaconda3\envs\new_env\Lib\site-packages\numpyro\infer\autoguide.py:412, in AutoNormal.__call__(self, *args, **kwargs)
#     409 def __call__(self, *args, **kwargs):
#     410     if self.prototype_trace is None:
#     411         # run model to inspect the model structure
# --> 412         self._setup_prototype(*args, **kwargs)
#     414     plates = self._create_plates(*args, **kwargs)
#     415     result = {}
#
# File z:\anaconda3\envs\new_env\Lib\site-packages\numpyro\infer\autoguide.py:387, in AutoNormal._setup_prototype(self, *args, **kwargs)
#     386 def _setup_prototype(self, *args, **kwargs):
# --> 387     super()._setup_prototype(*args, **kwargs)
#     389     for name, site in self.prototype_trace.items():
#     390         if site["type"] != "sample" or site["is_observed"]:
#
# File z:\anaconda3\envs\new_env\Lib\site-packages\numpyro\infer\autoguide.py:158, in AutoGuide._setup_prototype(self, *args, **kwargs)
#     151 rng_key = numpyro.prng_key()
#     152 with handlers.block():
#     153     (
#     154         init_params,
#     155         self._potential_fn_gen,
#     156         postprocess_fn_gen,
#     157         self.prototype_trace,
# --> 158     ) = initialize_model(
#     159         rng_key,
#     160         self.model,
#     161         init_strategy=self.init_loc_fn,
#     162         dynamic_args=True,
#     163         model_args=args,
#     164         model_kwargs=kwargs,
#     165     )
#     166 self._potential_fn = self._potential_fn_gen(*args, **kwargs)
#     167 postprocess_fn = postprocess_fn_gen(*args, **kwargs)
#
# File z:\anaconda3\envs\new_env\Lib\site-packages\numpyro\infer\util.py:663, in initialize_model(rng_key, model, init_strategy, dynamic_args, model_args, model_kwargs, forward_mode_differentiation, validate_grad)
#     653 model_kwargs = {} if model_kwargs is None else model_kwargs
#     654 substituted_model = substitute(
#     655     seed(model, rng_key if is_prng_key(rng_key) else rng_key[0]),
#     656     substitute_fn=init_strategy,
#     657 )
#     658 (
#     659     inv_transforms,
#     660     replay_model,
#     661     has_enumerate_support,
#     662     model_trace,
# --> 663 ) = _get_model_transforms(substituted_model, model_args, model_kwargs)
#     664 # substitute param sites from model_trace to model so
#     665 # we don't need to generate again parameters of `numpyro.module`
#     666 model = substitute(
#     667     model,
#     668     data={
#    (...)
#     672     },
#     673 )
#
# File z:\anaconda3\envs\new_env\Lib\site-packages\numpyro\infer\util.py:457, in _get_model_transforms(model, model_args, model_kwargs)
#     455 def _get_model_transforms(model, model_args=(), model_kwargs=None):
#     456     model_kwargs = {} if model_kwargs is None else model_kwargs
# --> 457     model_trace = trace(model).get_trace(*model_args, **model_kwargs)
#     458     inv_transforms = {}
#     459     # model code may need to be replayed in the presence of deterministic sites
#
# File z:\anaconda3\envs\new_env\Lib\site-packages\numpyro\handlers.py:186, in trace.get_trace(self, *args, **kwargs)
#     178 def get_trace(self, *args, **kwargs):
#     179     """
#     180     Run the wrapped callable and return the recorded trace.
#     181
#    (...)
#     184     :return: `OrderedDict` containing the execution trace.
#     185     """
# --> 186     self(*args, **kwargs)
#     187     return self.trace
#
# File z:\anaconda3\envs\new_env\Lib\site-packages\numpyro\primitives.py:105, in Messenger.__call__(self, *args, **kwargs)
#     103     return self
#     104 with self:
# --> 105     return self.fn(*args, **kwargs)
#
# File z:\anaconda3\envs\new_env\Lib\site-packages\numpyro\primitives.py:105, in Messenger.__call__(self, *args, **kwargs)
#     103     return self
#     104 with self:
# --> 105     return self.fn(*args, **kwargs)
#
# File z:\anaconda3\envs\new_env\Lib\site-packages\numpyro\primitives.py:105, in Messenger.__call__(self, *args, **kwargs)
#     103     return self
#     104 with self:
# --> 105     return self.fn(*args, **kwargs)
#
# Cell In[64], line 70, in model(rho_x, rho_y, rho_z, r, sigma_obs)
#      67 sb = numpyro.deterministic("sb", jnp.sum(density, axis = 2))
#      69 # Observation model
# ---> 70 numpyro.sample("sigma_obs", dist.Normal(sb, 0.2 * sb), obs=sigma_obs)
#
# File z:\anaconda3\envs\new_env\Lib\site-packages\numpyro\distributions\distribution.py:100, in DistributionMeta.__call__(cls, *args, **kwargs)
#      98     if result is not None:
#      99         return result
# --> 100 return super().__call__(*args, **kwargs)
#
# File z:\anaconda3\envs\new_env\Lib\site-packages\numpyro\distributions\continuous.py:2185, in Normal.__init__(self, loc, scale, validate_args)
#    2183 self.loc, self.scale = promote_shapes(loc, scale)
#    2184 batch_shape = lax.broadcast_shapes(jnp.shape(loc), jnp.shape(scale))
# -> 2185 super(Normal, self).__init__(
#    2186     batch_shape=batch_shape, validate_args=validate_args
#    2187 )
#
# File z:\anaconda3\envs\new_env\Lib\site-packages\numpyro\distributions\distribution.py:232, in Distribution.__init__(self, batch_shape, event_shape, validate_args)
#     230     self._validate_args = validate_args
#     231 if self._validate_args:
# --> 232     self.validate_args(strict=False)
#     233 super(Distribution, self).__init__()
#
# File z:\anaconda3\envs\new_env\Lib\site-packages\numpyro\distributions\distribution.py:260, in Distribution.validate_args(self, strict)
#     258 if not_jax_tracer(is_valid):
#     259     if not np.all(is_valid):
# --> 260         raise ValueError(
#     261             "{} distribution got invalid {} parameter.".format(
#     262                 self.__class__.__name__, param
#     263             )
#     264         )
#     265 elif strict:
#     266     raise RuntimeError("Cannot validate arguments inside jitted code.")
#
# ValueError: Normal distribution got invalid scale parameter.

# %%
#numpyro.render_model(model, model_args=(rho_x,rho_y,rho_z,r))

# %%
#plt.hist(posterior_samples['m'])

# %%
#posterior_samples['m'].mean()

# %%
#plt.hist(posterior_samples['h2'])

# %%
#plt.hist(posterior_samples['h3'])

# %%
#plt.hist(posterior_samples['h4'])

# %%
#plt.hist(posterior_samples['r_turn'])

# %%
#plt.hist(posterior_samples['smoothness'])

# %%
'''A = posterior_samples['A'].mean()

def mean_function(r):
    return jnp.cos(r)*A


x_test = np.linspace(0,10,1000)

plt.plot(x_test,mean_function(x_test))'''
# Out:
# "A = posterior_samples['A'].mean()\n\ndef mean_function(r):\n    return jnp.cos(r)*A\n\n\nx_test = np.linspace(0,10,1000)\n\nplt.plot(x_test,mean_function(x_test))"

# %%
adam_params = [0.2]
elbo_params = [10]
steps_param = [1000]

for i in range(len(adam_params)):
    for j in range(len(elbo_params)):
        for k in range(len(steps_param)):
            print(adam_params[i],elbo_params[j],steps_param[k])
            results, guide = runsvi(adam_params[i],elbo_params[j],noisy_data,steps_param[k],rho_x,rho_y,rho_z,r)

            key = jax.random.PRNGKey(42)

            predictive = Predictive(guide, params=results.params, num_samples=1000)
            posterior_samples = predictive(key,rho_x,rho_y,rho_z,r)

            predictive = Predictive(model, posterior_samples, params=results.params, num_samples=1000)
            posterior_predictive_samples = predictive(key,rho_x,rho_y,rho_z,r)


            p_mean = posterior_predictive_samples['p'].mean(axis=0)
            p_std = posterior_predictive_samples['p'].std(axis=0)

            sb_mean = posterior_predictive_samples['sb'].mean(axis=0)
            sb_std = posterior_predictive_samples['sb'].std(axis=0)

            plot_p_sample(adam_params[i],elbo_params[j],steps_param[k],p_mean,p_std,r_gp,p_a_def,p_b_def,p_c_def,p_d_def)

            plot_comparison(adam_params[i],elbo_params[j],steps_param[k],noisy_data,p_mean,sb_mean,sb_std,p_a_def,p_b_def,p_c_def,p_d_def)
# Out:
# 0.2 10 1000
# 100%|██████████| 1000/1000 [09:09<00:00,  1.82it/s, init loss: 66655796.0000, avg. loss [951-1000]: -22119.2256]

# %%
results.params.keys()
# Out:
# dict_keys(['length_scale_p_auto_loc', 'length_scale_p_auto_scale', 'p_not_transformed_auto_loc', 'p_not_transformed_auto_scale', 'sigma_p_auto_loc', 'sigma_p_auto_scale'])

# %%
loss = results.losses
num_steps = np.linspace(1,steps+1,steps)

plt.plot(num_steps,loss)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 loss = results.losses
# ----> 2 num_steps = np.linspace(1,steps+1,steps)
#       4 plt.plot(num_steps,loss)
#
# NameError: name 'steps' is not defined

# %%
loss_last_steps = loss[-100:]
num_steps = np.linspace(1,101,100)
plt.plot(num_steps,loss_last_steps)
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
key = jax.random.PRNGKey(42)

   
predictive = Predictive(guide, params=results.params, num_samples=1000)
posterior_samples = predictive(key,rho_x,rho_y,rho_z,r)

#plt.hist(posterior_samples['p_not_transformed'])
#posterior_samples
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
predictive = Predictive(model, posterior_samples, params=results.params, num_samples=1000)
posterior_predictive_samples = predictive(key,rho_x,rho_y,rho_z,r)


p_mean = posterior_predictive_samples['p'].mean(axis=0)
p_std = posterior_predictive_samples['p'].std(axis=0)

sb_mean = posterior_predictive_samples['sb'].mean(axis=0)
sb_std = posterior_predictive_samples['sb'].std(axis=0)
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
posterior_predictive_samples['p'].shape
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#sample = sample_p(results,model)
#sample['p'].shape
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#len(sample['p'][0])
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
plt.plot(posterior_predictive_samples['p'][0])
plt.plot(posterior_predictive_samples['p'][1000])
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
def p(r,p_a,p_b,p_c,p_d):
    p = p_a * r**3 + p_b * r**2 + p_c * r + p_d
    return p

r_gp = jnp.linspace(jnp.min(r)-0.05,jnp.max(r)+0.5,1000)

def plot_p_sample(p_mean,p_std,r_gp,p_a_def,p_b_def,p_c_def,p_d_def):
    
    p_obs = p(r_gp,p_a_def,p_b_def,p_c_def,p_d_def)


    # Plot p(r)
    plt.figure(figsize=(8, 6))
    plt.plot(r_gp, p_mean, label="Predicted p(r)")
    plt.plot(r_gp,p_obs, label="True p(r)")
    #plt.errorbar(r_gp,p_mean, yerr = p_std,ecolor ="blue")
    plt.fill_between(r_gp, p_mean - p_std, p_mean + p_std, alpha=0.2, label="Uncertainty")
    plt.xlabel("Radial distance (r)")
    plt.ylabel("p(r)")
    plt.title("Predicted p as a function of radial distance")
    plt.legend()
    plt.grid(True)
    plt.ylim(0,1)
    plt.show()


plot_p_sample(p_mean,p_std,r_gp,p_a_def,p_b_def,p_c_def,p_d_def)
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
def plot_comparison(noisy_data,p_mean,sb_mean,sb_std,p_a_def,p_b_def,p_c_def,p_d_def):


    interpolator = RegularGridInterpolator((r_gp,), p_mean, method="linear", bounds_error=False, fill_value=None)
    # Interpolate the values

    sorting_indices = jnp.argsort(r)  # Get indices that sort r_obs
    r_sorted = r[sorting_indices]  # Sort r_obs

    #p_sampled_full = interpolator(r)

    p_sampled_full_sorted = interpolator(r_sorted)
    p_obs = p(r_sorted,p_a_def,p_b_def,p_c_def,p_d_def)


    # Set up the figure and subplots
    fig, axes = plt.subplots(4, figsize=(8,16))


    #key = jax.random.PRNGKey(42)

    # Plot data in each subplot


    ax1 = axes[0]
    ax2 = axes[1]
    ax3 = axes[2]
    ax4 = axes[3]



    img1 = ax1.imshow(noisy_data.T, norm=colors.LogNorm(vmin=noisy_data.min(), vmax=noisy_data.max()), origin='lower',extent = extents)
    fig.colorbar(img1, ax=ax1, label='Color Scale')
    ax1.set_title("True p_a: "+str(p_a_def)+" True p_b: "+str(p_b_def)+" True p_c: "+str(p_c_def)+" True p_d: "+str(p_d_def))

    img2 = ax2.imshow(sb_mean.T, norm=colors.LogNorm(vmin=sb_mean.min(), vmax=sb_mean.max()), origin='lower',extent = extents)
    fig.colorbar(img2, ax=ax2, label='Color Scale')
    ax2.set_title("With predicted p")

    residual = (noisy_data - sb_mean)/sb_mean
    img3 = ax3.imshow(residual.T, origin='lower',extent = extents)
    fig.colorbar(img3, ax=ax3, label='Color Scale')
    score = utils.ssd_score(noisy_data,sb_mean,sb_mean)
    ax3.set_title("Residual Score: "+str(score))

    ax4.plot(r_sorted, p_obs, label="True function of p(r)")
    ax4.plot(r_sorted, p_sampled_full_sorted, label="Predicted function of p(r)")

    ax4.legend()
    ax4.set_xlabel('r')
    ax4.set_ylabel('p(r)')
    ax4.grid(True)
    ax4.set_ylim([0,1])


    # Adjust layout to avoid overlap
    plt.tight_layout()
    plt.show()


plot_comparison(noisy_data,p_mean,sb_mean,sb_std,p_a_def,p_b_def,p_c_def,p_d_def)
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
