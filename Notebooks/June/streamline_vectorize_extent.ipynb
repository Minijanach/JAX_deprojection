# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import jax.numpy as jnp
from jax import grad , vmap
from matplotlib.colors import LogNorm
from ipywidgets import interact, IntSlider
from jax.scipy.spatial.transform import Rotation as R

# %%
'''def _calculate_rho(x, y, z, e, p, q, rho0, s, a, b):
    r = ((jnp.abs(x)**(2 - e) + (jnp.abs(y) / p)**(2 - e) + (jnp.abs(z) / q)**(2 - e)))**(1 / (2 - e))
    
    # Apply the special case handling for r = 0
    special_case = r == 0

    # Calculate the denominator for the normal case elements
    normal_r = jnp.where(special_case, 1, r)  # Avoid division by zero by replacing zeros with ones
    den = rho0 / ((normal_r / s)**a * (1 + (normal_r / s))**(b - a))

    # Calculate the result, handling special cases where r = 0
    result = jnp.where(special_case, rho0 / (p * q), den / (p * q))

    return result'''


def _calculate_rho(x, y, z, e, p, q, rho0, s, a, b):
    r = ((jnp.abs(x)**(2 - e) + (jnp.abs(y) / p)**(2 - e) + (jnp.abs(z) / q)**(2 - e)))**(1 / (2 - e))
    den = rho0 / ((r / s)**a * (1 + (r / s))**(b - a))
    
    return den/(p*q)

def rho(x, y, z, e, p, q, rho0, s, a, b):
    # Convert inputs to arrays
    x = jnp.asarray(x)
    y = jnp.asarray(y)
    z = jnp.asarray(z)

    # Check if inputs are arrays or scalars
    if x.ndim == 0:  # Scalar input
        return _calculate_rho(x, y, z, e, p, q, rho0, s, a, b)
    else:  # Array input
        # Check if inputs have the same length
        if x.size != y.size or x.size != z.size or y.size != z.size:
            raise ValueError("Input arrays must have the same length!")
        
        # Check if the length of inputs is reshapeable into a cube
        cube_len = int(round(x.size ** (1/3)))
        if cube_len ** 3 != x.size:
            raise ValueError("The length of the inputs must be reshapeable into a cube!")

        return _calculate_rho(x, y, z, e, p, q, rho0, s, a, b).reshape((cube_len, cube_len, cube_len))

# %%
def _calculate_gradient_rho(x, y, z, e, p, q, rho0, s, a, b, arg_num):
    grad_rho = grad(rho, argnums=arg_num)
    return grad_rho(x, y, z, e, p, q, rho0, s, a, b)

def gradient_rho(x, y, z, e, p, q, rho0, s, a, b, arg_num):
    # Convert inputs to arrays
    x = np.asarray(x)
    y = np.asarray(y)
    z = np.asarray(z)
    
    if not arg_num:
        raise ValueError("arg_num cannot be empty. Specify the arguments to differentiate with respect to.")
    
    # Check if inputs are arrays or scalars
    if x.ndim == 0:  # Scalar input
        return _calculate_gradient_rho(x, y, z, e, p, q, rho0, s, a, b, arg_num)
    else:  # Array input
        # Check if inputs have the same length
        if x.size != y.size or x.size != z.size or y.size != z.size:
            raise ValueError("Input arrays must have the same length!")
        
        # Define the function to compute the gradient
        grad_rho = grad(rho, argnums=arg_num)

        # Vectorize the gradient function
        vmap_grad_rho = vmap(lambda x, y, z: grad_rho(x, y, z, e, p, q, rho0, s, a, b), in_axes=(0, 0, 0))

        # Compute the gradients
        gradients = vmap_grad_rho(x, y, z)

        # Reshape and stack the gradients
        cube_len = int(round(x.size ** (1/3)))
        reshaped_gradients = [jnp.reshape(g, (cube_len, cube_len, cube_len)) for g in gradients]

        # Stack gradients along the last axis
        stacked_gradients = jnp.stack(reshaped_gradients, axis=-1)
        
        return stacked_gradients

# %%
def rotation(x,y,z,angle,axis):

    x = jnp.asarray(x)
    y = jnp.asarray(y)
    z = jnp.asarray(z)

    if(x.size!= y.size or x.size!= z.size or y.size!= z.size):
        raise ValueError("Input must have the same length!")

    if axis not in ['x', 'y', 'z']:
        raise ValueError("axis has to be either x , y or z!")
    
    rotation = R.from_euler(axis, angle, degrees=True)

    coordinates = jnp.array([x, y, z]).T
    
    rotated_coordinates = rotation.apply(coordinates)

    res = rotated_coordinates.T
    
    x_rot, y_rot, z_rot = res[0], res[1], res[2]

    return x_rot, y_rot, z_rot

# %%
'''def plot_img(proj_density_mat, extent, title = '' ):
    plt.imshow(proj_density_mat.T, origin= 'lower', extent=extent)
    plt.colorbar(label='Color Scale')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title(title)
    plt.show()'''


def plot_img(proj_density_mat, extent, title = '' ):
    plt.imshow(proj_density_mat.T, origin= 'lower', extent=extent)
    cbar = plt.colorbar(label='Color Scale')
    #cbar.set_ticks([np.min(proj_density_mat), np.max(proj_density_mat)])

    # Optionally, set tick labels to the min and max of your data
    #cbar.set_ticklabels([np.min(proj_density_mat), np.max(proj_density_mat)])

    min_val = np.min(proj_density_mat)
    max_val = np.max(proj_density_mat   )
    num_ticks = 5  # Number of ticks between min and max
    ticks = np.linspace(min_val, max_val, num_ticks + 2)[1:-1]  # Exclude min and max
    cbar.set_ticks(ticks)

    # Optionally, set tick labels to match the ticks
    cbar.set_ticklabels(["{:.8f}".format(tick) for tick in ticks])



    plt.xlabel('x')
    plt.ylabel('y')
    plt.title(title)
    plt.show()

# %%
def plot_img_logscale(proj_density_mat):
    """
    Plot a 2D image with a logarithmically scaled colour bar.

    Parameters:
    - proj_density_mat (numpy.ndarray): The 2D density matrix representing the density distribution projected along the z-axis.
                                   

    Returns:
    None

    This function uses Plotly matplotlib
    to create and display an image plot of the projected density with a logarithmically scaled colour bar..
    """
    plt.imshow(proj_density_mat.T, norm=colors.LogNorm(vmin=proj_density_mat.min(), vmax=proj_density_mat.max()), origin='lower')
    plt.colorbar(label='Color Scale')
    plt.show()

# %%
s = 1. 
e = 0.5
p = 0.8
q = 0.5
a = 2.
b = 4.
rho0 = 1.


# Define the size of your 3D matrix
x_size, y_size, z_size = 400, 400, 400
ex = 50

# Create 3D coordinates
x, y, z = np.meshgrid(np.linspace(-ex, ex, x_size),
                      np.linspace(-ex, ex, y_size),
                      np.linspace(-ex, ex, z_size), indexing = 'ij')
x = x.flatten()
y = y.flatten()
z = z.flatten()

# %%
density = rho(x,y,z,e,p,q,rho0,s,a,b)

density = np.sum(density, axis = 2)
extent = [-ex, ex,-ex, ex]
plot_img_logscale(density)

# %%
'''x = np.linspace(-ex, ex, x_size)
y = np.linspace(-ex, ex, y_size)

plt.contour(x, y, density.T, levels=[0.5,1,2,4,8,16,100], colors='b')
#plt.gca().set_aspect('equal', adjustable='box')
'''
# Out:
# "x = np.linspace(-ex, ex, x_size)\ny = np.linspace(-ex, ex, y_size)\n\nplt.contour(x, y, density.T, levels=[0.5,1,2,4,8,16,100], colors='b')\n#plt.gca().set_aspect('equal', adjustable='box')\n"

# %%
np.min(density)
# Out:
# Array(7.090255e-06, dtype=float32)

# %%
np.max(density)
# Out:
# Array(21.600687, dtype=float32)

# %%
list_args = [0,1,2,3,4,5]
gradient_01 = gradient_rho(x,y,z,e,p,q,rho0,s,a,b,list_args)

# %%
gradx = gradient_01[:,:,:,0]
gradx = np.sum(gradx, axis=2)
grady = gradient_01[:,:,:,1]
grady = np.sum(grady, axis=2)
gradz = gradient_01[:,:,:,2]
gradz = np.sum(gradz, axis=2)
grade = gradient_01[:,:,:,3]
grade = np.sum(grade, axis=2)
gradp = gradient_01[:,:,:,4]
gradp = np.sum(gradp, axis=2)
gradq = gradient_01[:,:,:,5]
gradq = np.sum(gradq, axis=2)

# %%
plot_img(gradx,extent, 'drho/dx projected along z-axis')

# %%
plot_img(grady,extent, 'drho/dy projected along z-axis')

# %%
plot_img(gradz,extent, 'drho/dz projected along z-axis')

# %%
plot_img(grade,extent, 'drho/de projected along z-axis')
# Only works while using abs on x,y,z

# %%
plot_img(gradp,extent, 'drho/dp projected along z-axis')

# %%
plot_img(gradq,extent, 'drho/dq projected along z-axis')

# %%
np.min(gradq)
# Out:
# Array(-1.7074752e-05, dtype=float32)

# %%
np.max(gradq)
# Out:
# Array(24.38935, dtype=float32)

# %%
np.mean(gradq)
# Out:
# Array(0.00079809, dtype=float32)

# %%
gradq
# Out:
# Array([[-3.8189110e-06, -3.8393273e-06, -3.8598419e-06, ...,
#         -3.8598419e-06, -3.8393273e-06, -3.8189110e-06],
#        [-3.8335043e-06, -3.8540284e-06, -3.8746521e-06, ...,
#         -3.8746521e-06, -3.8540284e-06, -3.8335043e-06],
#        [-3.8481380e-06, -3.8687695e-06, -3.8895023e-06, ...,
#         -3.8895023e-06, -3.8687695e-06, -3.8481380e-06],
#        ...,
#        [-3.8481380e-06, -3.8687695e-06, -3.8895023e-06, ...,
#         -3.8895023e-06, -3.8687695e-06, -3.8481380e-06],
#        [-3.8335043e-06, -3.8540284e-06, -3.8746521e-06, ...,
#         -3.8746521e-06, -3.8540284e-06, -3.8335043e-06],
#        [-3.8189110e-06, -3.8393273e-06, -3.8598419e-06, ...,
#         -3.8598419e-06, -3.8393273e-06, -3.8189110e-06]], dtype=float32)

# %%
rot_x , rot_y , rot_z = rotation(x,y,z,45,'z')

rot_density = rho(rot_x,rot_y,rot_z,e,p,q,rho0,s,a,b)

rot_density = np.sum(rot_density, axis = 2)

extent = [np.min(rot_x),np.max(rot_x),np.min(rot_y),np.max(rot_y)]
plot_img(rot_density,extent, 'projected density along z-axis rotated by 45 degrees')

# %%
s = 1. 
e = 0.5
p = 0.8
q = [0.1,0.3,0.5,0.7,1.]
a = 2.
b = 4.
rho0 = 1.
ex = [0.01,0.1,1,10,50]
Num = [10,50,100,200,400]

minis = []
maxis = []
means = []

for i in range(len(Num)):
    for j in range(len(ex)):
        for k in range(len(q)):
        # Define the size of your 3D matrix
            size = Num[i]
            ext = ex[j]

            # Create 3D coordinates
            x, y, z = np.meshgrid(np.linspace(-ext, ext, size),
                                np.linspace(-ext, ext, size),
                                np.linspace(-ext, ext, size), indexing = 'ij')
            x = x.flatten()
            y = y.flatten()
            z = z.flatten()


            list_args = [5]
            gradient_02 = gradient_rho(x,y,z,e,p,q[k],rho0,s,a,b,list_args)

            gradqq = gradient_02[:,:,:,0]
            gradqq = np.sum(gradqq, axis=2)

            mini = np.min(gradqq)
            maxi = np.max(gradqq)
            mean = np.mean(gradqq)

            minis.append(mini)
            maxis.append(maxi)
            means.append(mean)

            print("For N = "+str(size)+" , extent = "+str(-ext)+" - "+str(ext)+" , q = "+str(q[k])+" :")
            print("Minimum of the gradient q : "+str(mini))
            print("Maximum of the gradient q : "+str(maxi))
            print("Mean of the gradient q : "+str(mean)+"\n")
# Out:
# For N = 10 , extent = -0.01 - 0.01 , q = 0.1 :
# Minimum of the gradient q : 14974.195
# Maximum of the gradient q : 1937219.1
# Mean of the gradient q : 459474.5
#
# For N = 10 , extent = -0.01 - 0.01 , q = 0.3 :
# Minimum of the gradient q : -67162.125
# Maximum of the gradient q : 878639.25
# Mean of the gradient q : -1040.2494
#
# For N = 10 , extent = -0.01 - 0.01 , q = 0.5 :
# Minimum of the gradient q : -69508.586
# Maximum of the gradient q : 330345.97
# Mean of the gradient q : -42973.66
#
# For N = 10 , extent = -0.01 - 0.01 , q = 0.7 :
# Minimum of the gradient q : -69853.18
# Maximum of the gradient q : 97909.28
# Mean of the gradient q : -47304.0
#
# For N = 10 , extent = -0.01 - 0.01 , q = 1.0 :
# Minimum of the gradient q : -71266.49
# Maximum of the gradient q : -21899.973
# Mean of the gradient q : -41787.69
#
# For N = 10 , extent = -0.1 - 0.1 , q = 0.1 :
# Minimum of the gradient q : 556.55756
# Maximum of the gradient q : 18257.318
# Mean of the gradient q : 4604.402
#
# For N = 10 , extent = -0.1 - 0.1 , q = 0.3 :
# Minimum of the gradient q : -341.47733
# Maximum of the gradient q : 8865.8125
# Mean of the gradient q : 307.0572
#
# For N = 10 , extent = -0.1 - 0.1 , q = 0.5 :
# Minimum of the gradient q : -450.78574
# Maximum of the gradient q : 3489.6296
# Mean of the gradient q : -208.29422
#
# For N = 10 , extent = -0.1 - 0.1 , q = 0.7 :
# Minimum of the gradient q : -509.20987
# Maximum of the gradient q : 1160.9597
# Mean of the gradient q : -314.4145
#
# For N = 10 , extent = -0.1 - 0.1 , q = 1.0 :
# Minimum of the gradient q : -567.5171
# Maximum of the gradient q : -99.368225
# Mean of the gradient q : -313.77692
#
# For N = 10 , extent = -1 - 1 , q = 0.1 :
# Minimum of the gradient q : 1.75165
# Maximum of the gradient q : 76.37491
# Mean of the gradient q : 16.993805
#
# For N = 10 , extent = -1 - 1 , q = 0.3 :
# Minimum of the gradient q : -0.19113912
# Maximum of the gradient q : 65.19161
# Mean of the gradient q : 4.3174605
#
# For N = 10 , extent = -1 - 1 , q = 0.5 :
# Minimum of the gradient q : -0.4500993
# Maximum of the gradient q : 31.268965
# Mean of the gradient q : 1.1732705
#
# For N = 10 , extent = -1 - 1 , q = 0.7 :
# Minimum of the gradient q : -0.7405402
# Maximum of the gradient q : 13.749313
# Mean of the gradient q : 0.08153217
#
# For N = 10 , extent = -1 - 1 , q = 1.0 :
# Minimum of the gradient q : -1.2094073
# Maximum of the gradient q : 3.3385305
# Mean of the gradient q : -0.45876822
#
# For N = 10 , extent = -10 - 10 , q = 0.1 :
# Minimum of the gradient q : 0.0004237878
# Maximum of the gradient q : 0.030073928
# Mean of the gradient q : 0.0057451604
#
# For N = 10 , extent = -10 - 10 , q = 0.3 :
# Minimum of the gradient q : -2.2825858e-05
# Maximum of the gradient q : 0.07044849
# Mean of the gradient q : 0.004182245
#
# For N = 10 , extent = -10 - 10 , q = 0.5 :
# Minimum of the gradient q : -6.510441e-05
# Maximum of the gradient q : 0.05085437
# Mean of the gradient q : 0.0023230405
#
# For N = 10 , extent = -10 - 10 , q = 0.7 :
# Minimum of the gradient q : -0.00012560977
# Maximum of the gradient q : 0.02884042
# Mean of the gradient q : 0.0011544708
#
# For N = 10 , extent = -10 - 10 , q = 1.0 :
# Minimum of the gradient q : -0.00024858117
# Maximum of the gradient q : 0.011230249
# Mean of the gradient q : 0.00033235046
#
# For N = 10 , extent = -50 - 50 , q = 0.1 :
# Minimum of the gradient q : 7.4620107e-07
# Maximum of the gradient q : 5.71548e-05
# Mean of the gradient q : 1.0658692e-05
#
# For N = 10 , extent = -50 - 50 , q = 0.3 :
# Minimum of the gradient q : -3.653843e-08
# Maximum of the gradient q : 0.00016954972
# Mean of the gradient q : 9.741332e-06
#
# For N = 10 , extent = -50 - 50 , q = 0.5 :
# Minimum of the gradient q : -1.0723117e-07
# Maximum of the gradient q : 0.00014089476
# Mean of the gradient q : 6.3578773e-06
#
# For N = 10 , extent = -50 - 50 , q = 0.7 :
# Minimum of the gradient q : -2.0971163e-07
# Maximum of the gradient q : 8.7529756e-05
# Mean of the gradient q : 3.5823264e-06
#
# For N = 10 , extent = -50 - 50 , q = 1.0 :
# Minimum of the gradient q : -4.2617643e-07
# Maximum of the gradient q : 3.7550064e-05
# Mean of the gradient q : 1.315864e-06
#
# For N = 50 , extent = -0.01 - 0.01 , q = 0.1 :
# Minimum of the gradient q : -447297.5
# Maximum of the gradient q : 59804660.0
# Mean of the gradient q : 414999.66
#
# For N = 50 , extent = -0.01 - 0.01 , q = 0.3 :
# Minimum of the gradient q : -511800.62
# Maximum of the gradient q : 28303954.0
# Mean of the gradient q : -367500.28
#
# For N = 50 , extent = -0.01 - 0.01 , q = 0.5 :
# Minimum of the gradient q : -526358.75
# Maximum of the gradient q : 12006092.0
# Mean of the gradient q : -369653.25
#
# For N = 50 , extent = -0.01 - 0.01 , q = 0.7 :
# Minimum of the gradient q : -532698.0
# Maximum of the gradient q : 5066672.5
# Mean of the gradient q : -326880.78
#
# For N = 50 , extent = -0.01 - 0.01 , q = 1.0 :
# Minimum of the gradient q : -537588.1
# Maximum of the gradient q : 1335936.5
# Mean of the gradient q : -262844.53
#
# For N = 50 , extent = -0.1 - 0.1 , q = 0.1 :
# Minimum of the gradient q : -1236.8164
# Maximum of the gradient q : 592147.0
# Mean of the gradient q : 7274.783
#
# For N = 50 , extent = -0.1 - 0.1 , q = 0.3 :
# Minimum of the gradient q : -2956.252
# Maximum of the gradient q : 283575.28
# Mean of the gradient q : -1698.9242
#
# For N = 50 , extent = -0.1 - 0.1 , q = 0.5 :
# Minimum of the gradient q : -3708.593
# Maximum of the gradient q : 121146.2
# Mean of the gradient q : -2419.1123
#
# For N = 50 , extent = -0.1 - 0.1 , q = 0.7 :
# Minimum of the gradient q : -4119.3193
# Maximum of the gradient q : 51718.88
# Mean of the gradient q : -2373.522
#
# For N = 50 , extent = -0.1 - 0.1 , q = 1.0 :
# Minimum of the gradient q : -4472.0303
# Maximum of the gradient q : 14232.861
# Mean of the gradient q : -2048.134
#
# For N = 50 , extent = -1 - 1 , q = 0.1 :
# Minimum of the gradient q : -0.28812075
# Maximum of the gradient q : 5027.303
# Mean of the gradient q : 66.487526
#
# For N = 50 , extent = -1 - 1 , q = 0.3 :
# Minimum of the gradient q : -2.3681278
# Maximum of the gradient q : 2693.5479
# Mean of the gradient q : 6.349146
#
# For N = 50 , extent = -1 - 1 , q = 0.5 :
# Minimum of the gradient q : -5.185705
# Maximum of the gradient q : 1192.8003
# Mean of the gradient q : -0.8652098
#
# For N = 50 , extent = -1 - 1 , q = 0.7 :
# Minimum of the gradient q : -8.153317
# Maximum of the gradient q : 532.5498
# Mean of the gradient q : -3.1989672
#
# For N = 50 , extent = -1 - 1 , q = 1.0 :
# Minimum of the gradient q : -12.351042
# Maximum of the gradient q : 170.66379
# Mean of the gradient q : -4.25428
#
# For N = 50 , extent = -10 - 10 , q = 0.1 :
# Minimum of the gradient q : -1.7672894e-05
# Maximum of the gradient q : 12.141983
# Mean of the gradient q : 0.1191761
#
# For N = 50 , extent = -10 - 10 , q = 0.3 :
# Minimum of the gradient q : -0.00032833603
# Maximum of the gradient q : 14.086267
# Mean of the gradient q : 0.037899036
#
# For N = 50 , extent = -10 - 10 , q = 0.5 :
# Minimum of the gradient q : -0.00089136953
# Maximum of the gradient q : 7.5293627
# Mean of the gradient q : 0.014839071
#
# For N = 50 , extent = -10 - 10 , q = 0.7 :
# Minimum of the gradient q : -0.0017068284
# Maximum of the gradient q : 3.667707
# Mean of the gradient q : 0.0059804856
#
# For N = 50 , extent = -10 - 10 , q = 1.0 :
# Minimum of the gradient q : -0.0033607977
# Maximum of the gradient q : 1.3088754
# Mean of the gradient q : 0.0011724435
#
# For N = 50 , extent = -50 - 50 , q = 0.1 :
# Minimum of the gradient q : -2.3959274e-08
# Maximum of the gradient q : 0.041519977
# Mean of the gradient q : 0.00036034902
#
# For N = 50 , extent = -50 - 50 , q = 0.3 :
# Minimum of the gradient q : -5.3964504e-07
# Maximum of the gradient q : 0.09512103
# Mean of the gradient q : 0.00022950703
#
# For N = 50 , extent = -50 - 50 , q = 0.5 :
# Minimum of the gradient q : -1.4923417e-06
# Maximum of the gradient q : 0.06797916
# Mean of the gradient q : 0.0001281738
#
# For N = 50 , extent = -50 - 50 , q = 0.7 :
# Minimum of the gradient q : -2.91193e-06
# Maximum of the gradient q : 0.038549162
# Mean of the gradient q : 6.6633285e-05
#
# For N = 50 , extent = -50 - 50 , q = 1.0 :
# Minimum of the gradient q : -5.9006215e-06
# Maximum of the gradient q : 0.015490595
# Mean of the gradient q : 2.4364012e-05
#
# For N = 100 , extent = -0.01 - 0.01 , q = 0.1 :
# Minimum of the gradient q : -953558.06
# Maximum of the gradient q : 245346270.0
# Mean of the gradient q : -48112.03
#
# For N = 100 , extent = -0.01 - 0.01 , q = 0.3 :
# Minimum of the gradient q : -1086443.4
# Maximum of the gradient q : 116719800.0
# Mean of the gradient q : -847711.44
#
# For N = 100 , extent = -0.01 - 0.01 , q = 0.5 :
# Minimum of the gradient q : -1116275.5
# Maximum of the gradient q : 50191256.0
# Mean of the gradient q : -784636.5
#
# For N = 100 , extent = -0.01 - 0.01 , q = 0.7 :
# Minimum of the gradient q : -1129452.0
# Maximum of the gradient q : 21866136.0
# Mean of the gradient q : -679310.75
#
# For N = 100 , extent = -0.01 - 0.01 , q = 1.0 :
# Minimum of the gradient q : -1139466.8
# Maximum of the gradient q : 6636849.0
# Mean of the gradient q : -540432.5
#
# For N = 100 , extent = -0.1 - 0.1 , q = 0.1 :
# Minimum of the gradient q : -2739.3071
# Maximum of the gradient q : 2441601.0
# Mean of the gradient q : 6219.2017
#
# For N = 100 , extent = -0.1 - 0.1 , q = 0.3 :
# Minimum of the gradient q : -6383.494
# Maximum of the gradient q : 1168302.4
# Mean of the gradient q : -4453.162
#
# For N = 100 , extent = -0.1 - 0.1 , q = 0.5 :
# Minimum of the gradient q : -7952.5723
# Maximum of the gradient q : 504119.56
# Mean of the gradient q : -5254.362
#
# For N = 100 , extent = -0.1 - 0.1 , q = 0.7 :
# Minimum of the gradient q : -8804.555
# Maximum of the gradient q : 220797.77
# Mean of the gradient q : -4978.6357
#
# For N = 100 , extent = -0.1 - 0.1 , q = 1.0 :
# Minimum of the gradient q : -9535.492
# Maximum of the gradient q : 68142.625
# Mean of the gradient q : -4229.107
#
# For N = 100 , extent = -1 - 1 , q = 0.1 :
# Minimum of the gradient q : -0.79298043
# Maximum of the gradient q : 22566.8
# Mean of the gradient q : 78.48703
#
# For N = 100 , extent = -1 - 1 , q = 0.3 :
# Minimum of the gradient q : -5.4548664
# Maximum of the gradient q : 11395.284
# Mean of the gradient q : 4.609761
#
# For N = 100 , extent = -1 - 1 , q = 0.5 :
# Minimum of the gradient q : -11.74803
# Maximum of the gradient q : 5004.2427
# Mean of the gradient q : -4.5532665
#
# For N = 100 , extent = -1 - 1 , q = 0.7 :
# Minimum of the gradient q : -18.263426
# Maximum of the gradient q : 2239.9253
# Mean of the gradient q : -7.737475
#
# For N = 100 , extent = -1 - 1 , q = 1.0 :
# Minimum of the gradient q : -27.39265
# Maximum of the gradient q : 739.6263
# Mean of the gradient q : -9.149777
#
# For N = 100 , extent = -10 - 10 , q = 0.1 :
# Minimum of the gradient q : -8.797628e-05
# Maximum of the gradient q : 100.130356
# Mean of the gradient q : 0.27080613
#
# For N = 100 , extent = -10 - 10 , q = 0.3 :
# Minimum of the gradient q : -0.0007815275
# Maximum of the gradient q : 82.36674
# Mean of the gradient q : 0.058903545
#
# For N = 100 , extent = -10 - 10 , q = 0.5 :
# Minimum of the gradient q : -0.0021164226
# Maximum of the gradient q : 39.956776
# Mean of the gradient q : 0.02004654
#
# For N = 100 , extent = -10 - 10 , q = 0.7 :
# Minimum of the gradient q : -0.0040422203
# Maximum of the gradient q : 18.683819
# Mean of the gradient q : 0.007147927
#
# For N = 100 , extent = -10 - 10 , q = 1.0 :
# Minimum of the gradient q : -0.0079296995
# Maximum of the gradient q : 6.5024734
# Mean of the gradient q : 0.00053093134
#
# For N = 100 , extent = -50 - 50 , q = 0.1 :
# Minimum of the gradient q : -1.4141557e-07
# Maximum of the gradient q : 0.5561026
# Mean of the gradient q : 0.0012533468
#
# For N = 100 , extent = -50 - 50 , q = 0.3 :
# Minimum of the gradient q : -1.2881505e-06
# Maximum of the gradient q : 0.99792707
# Mean of the gradient q : 0.0006268065
#
# For N = 100 , extent = -50 - 50 , q = 0.5 :
# Minimum of the gradient q : -3.5607118e-06
# Maximum of the gradient q : 0.63183117
# Mean of the gradient q : 0.0003066504
#
# For N = 100 , extent = -50 - 50 , q = 0.7 :
# Minimum of the gradient q : -6.944907e-06
# Maximum of the gradient q : 0.33467045
# Mean of the gradient q : 0.000148013
#
# For N = 100 , extent = -50 - 50 , q = 1.0 :
# Minimum of the gradient q : -1.4068315e-05
# Maximum of the gradient q : 0.12724185
# Mean of the gradient q : 5.095614e-05
#
# For N = 200 , extent = -0.01 - 0.01 , q = 0.1 :
# Minimum of the gradient q : -1975028.5
# Maximum of the gradient q : 993789800.0
# Mean of the gradient q : -1023567.25
#
# For N = 200 , extent = -0.01 - 0.01 , q = 0.3 :
# Minimum of the gradient q : -2244984.0
# Maximum of the gradient q : 473999500.0
# Mean of the gradient q : -1811663.4
#
# For N = 200 , extent = -0.01 - 0.01 , q = 0.5 :
# Minimum of the gradient q : -2305514.0
# Maximum of the gradient q : 205195600.0
# Mean of the gradient q : -1615715.1
#
# For N = 200 , extent = -0.01 - 0.01 , q = 0.7 :
# Minimum of the gradient q : -2332231.0
# Maximum of the gradient q : 90756664.0
# Mean of the gradient q : -1384675.0
#
# For N = 200 , extent = -0.01 - 0.01 , q = 1.0 :
# Minimum of the gradient q : -2352458.0
# Maximum of the gradient q : 29231596.0
# Mean of the gradient q : -1095829.1
#
# For N = 200 , extent = -0.1 - 0.1 , q = 0.1 :
# Minimum of the gradient q : -5798.09
# Maximum of the gradient q : 9914106.0
# Mean of the gradient q : 3471.7268
#
# For N = 200 , extent = -0.1 - 0.1 , q = 0.3 :
# Minimum of the gradient q : -13315.805
# Maximum of the gradient q : 4742236.5
# Mean of the gradient q : -10003.03
#
# For N = 200 , extent = -0.1 - 0.1 , q = 0.5 :
# Minimum of the gradient q : -16524.727
# Maximum of the gradient q : 2056401.8
# Mean of the gradient q : -10937.201
#
# For N = 200 , extent = -0.1 - 0.1 , q = 0.7 :
# Minimum of the gradient q : -18262.383
# Maximum of the gradient q : 911870.56
# Mean of the gradient q : -10194.277
#
# For N = 200 , extent = -0.1 - 0.1 , q = 1.0 :
# Minimum of the gradient q : -19749.797
# Maximum of the gradient q : 295889.25
# Mean of the gradient q : -8593.337
#
# For N = 200 , extent = -1 - 1 , q = 0.1 :
# Minimum of the gradient q : -1.7539101
# Maximum of the gradient q : 95401.586
# Mean of the gradient q : 84.6948
#
# For N = 200 , extent = -1 - 1 , q = 0.3 :
# Minimum of the gradient q : -11.842102
# Maximum of the gradient q : 46844.227
# Mean of the gradient q : 0.15675598
#
# For N = 200 , extent = -1 - 1 , q = 0.5 :
# Minimum of the gradient q : -25.216034
# Maximum of the gradient q : 20490.574
# Mean of the gradient q : -12.166271
#
# For N = 200 , extent = -1 - 1 , q = 0.7 :
# Minimum of the gradient q : -38.921753
# Maximum of the gradient q : 9183.79
# Mean of the gradient q : -16.902407
#
# For N = 200 , extent = -1 - 1 , q = 1.0 :
# Minimum of the gradient q : -57.97888
# Maximum of the gradient q : 3076.7368
# Mean of the gradient q : -18.970394
#
# For N = 200 , extent = -10 - 10 , q = 0.1 :
# Minimum of the gradient q : -0.00019883644
# Maximum of the gradient q : 626.8737
# Mean of the gradient q : 0.47029045
#
# For N = 200 , extent = -10 - 10 , q = 0.3 :
# Minimum of the gradient q : -0.0017420426
# Maximum of the gradient q : 400.20297
# Mean of the gradient q : 0.07486873
#
# For N = 200 , extent = -10 - 10 , q = 0.5 :
# Minimum of the gradient q : -0.0047073066
# Maximum of the gradient q : 183.75847
# Mean of the gradient q : 0.02262257
#
# For N = 200 , extent = -10 - 10 , q = 0.7 :
# Minimum of the gradient q : -0.008970737
# Maximum of the gradient q : 84.11344
# Mean of the gradient q : 0.0065352707
#
# For N = 200 , extent = -10 - 10 , q = 1.0 :
# Minimum of the gradient q : -0.017538369
# Maximum of the gradient q : 28.90929
# Mean of the gradient q : -0.0016442762
#
# For N = 200 , extent = -50 - 50 , q = 0.1 :
# Minimum of the gradient q : -3.2150365e-07
# Maximum of the gradient q : 6.184664
# Mean of the gradient q : 0.0037082122
#
# For N = 200 , extent = -50 - 50 , q = 0.3 :
# Minimum of the gradient q : -2.878398e-06
# Maximum of the gradient q : 7.984736
# Mean of the gradient q : 0.0013267976
#
# For N = 200 , extent = -50 - 50 , q = 0.5 :
# Minimum of the gradient q : -7.953204e-06
# Maximum of the gradient q : 4.426567
# Mean of the gradient q : 0.00055766595
#
# For N = 200 , extent = -50 - 50 , q = 0.7 :
# Minimum of the gradient q : -1.550588e-05
# Maximum of the gradient q : 2.1935642
# Mean of the gradient q : 0.00024871764
#
# For N = 200 , extent = -50 - 50 , q = 1.0 :
# Minimum of the gradient q : -3.139081e-05
# Maximum of the gradient q : 0.79407537
# Mean of the gradient q : 7.959366e-05
#
# For N = 400 , extent = -0.01 - 0.01 , q = 0.1 :
# Minimum of the gradient q : -4027712.0
# Maximum of the gradient q : 4000117500.0
# Mean of the gradient q : -2996142.5
#
# For N = 400 , extent = -0.01 - 0.01 , q = 0.3 :
# Minimum of the gradient q : -4572226.0
# Maximum of the gradient q : 1910350200.0
# Mean of the gradient q : -3741292.8
#
# For N = 400 , extent = -0.01 - 0.01 , q = 0.5 :
# Minimum of the gradient q : -4694248.0
# Maximum of the gradient q : 829737540.0
# Mean of the gradient q : -3278425.0
#
# For N = 400 , extent = -0.01 - 0.01 , q = 0.7 :
# Minimum of the gradient q : -4748034.0
# Maximum of the gradient q : 369701020.0
# Mean of the gradient q : -2795656.2
#
# For N = 400 , extent = -0.01 - 0.01 , q = 1.0 :
# Minimum of the gradient q : -4788998.0
# Maximum of the gradient q : 122387250.0
# Mean of the gradient q : -2206732.8
#
# For N = 400 , extent = -0.1 - 0.1 , q = 0.1 :
# Minimum of the gradient q : -11972.734
# Maximum of the gradient q : 39953544.0
# Mean of the gradient q : -2323.6692
#
# For N = 400 , extent = -0.1 - 0.1 , q = 0.3 :
# Minimum of the gradient q : -27264.312
# Maximum of the gradient q : 19108024.0
# Mean of the gradient q : -21123.348
#
# For N = 400 , extent = -0.1 - 0.1 , q = 0.5 :
# Minimum of the gradient q : -33760.594
# Maximum of the gradient q : 8306305.5
# Mean of the gradient q : -22309.062
#
# For N = 400 , extent = -0.1 - 0.1 , q = 0.7 :
# Minimum of the gradient q : -37272.72
# Maximum of the gradient q : 3705649.0
# Mean of the gradient q : -20628.275
#
# For N = 400 , extent = -0.1 - 0.1 , q = 1.0 :
# Minimum of the gradient q : -40276.875
# Maximum of the gradient q : 1231043.8
# Mean of the gradient q : -17322.957
#
# For N = 400 , extent = -1 - 1 , q = 0.1 :
# Minimum of the gradient q : -3.7333984
# Maximum of the gradient q : 392026.5
# Mean of the gradient q : 86.65552
#
# For N = 400 , extent = -1 - 1 , q = 0.3 :
# Minimum of the gradient q : -24.850464
# Maximum of the gradient q : 189921.56
# Mean of the gradient q : -9.270461
#
# For N = 400 , extent = -1 - 1 , q = 0.5 :
# Minimum of the gradient q : -52.518433
# Maximum of the gradient q : 82916.65
# Mean of the gradient q : -27.516747
#
# For N = 400 , extent = -1 - 1 , q = 0.7 :
# Minimum of the gradient q : -80.702515
# Maximum of the gradient q : 37187.848
# Mean of the gradient q : -35.278145
#
# For N = 400 , extent = -1 - 1 , q = 1.0 :
# Minimum of the gradient q : -119.72473
# Maximum of the gradient q : 12547.504
# Mean of the gradient q : -38.62705
#
# For N = 400 , extent = -10 - 10 , q = 0.1 :
# Minimum of the gradient q : -0.0004268922
# Maximum of the gradient q : 3191.2793
# Mean of the gradient q : 0.65300435
#
# For N = 400 , extent = -10 - 10 , q = 0.3 :
# Minimum of the gradient q : -0.0037332475
# Maximum of the gradient q : 1759.3983
# Mean of the gradient q : 0.08397705
#
# For N = 400 , extent = -10 - 10 , q = 0.5 :
# Minimum of the gradient q : -0.010068417
# Maximum of the gradient q : 786.2472
# Mean of the gradient q : 0.022100685
#
# For N = 400 , extent = -10 - 10 , q = 0.7 :
# Minimum of the gradient q : -0.019150376
# Maximum of the gradient q : 356.2411
# Mean of the gradient q : 0.0033159915
#
# For N = 400 , extent = -10 - 10 , q = 1.0 :
# Minimum of the gradient q : -0.03733182
# Maximum of the gradient q : 121.715485
# Mean of the gradient q : -0.0065793064
#
# For N = 400 , extent = -50 - 50 , q = 0.1 :
# Minimum of the gradient q : -6.907285e-07
# Maximum of the gradient q : 53.985004
# Mean of the gradient q : 0.00884508
#
# For N = 400 , extent = -50 - 50 , q = 0.3 :
# Minimum of the gradient q : -6.181828e-06
# Maximum of the gradient q : 49.029663
# Mean of the gradient q : 0.0021710652
#
# For N = 400 , extent = -50 - 50 , q = 0.5 :
# Minimum of the gradient q : -1.7074752e-05
# Maximum of the gradient q : 24.38935
# Mean of the gradient q : 0.000798092
#
# For N = 400 , extent = -50 - 50 , q = 0.7 :
# Minimum of the gradient q : -3.3279182e-05
# Maximum of the gradient q : 11.523537
# Mean of the gradient q : 0.0003328391
#
# For N = 400 , extent = -50 - 50 , q = 1.0 :
# Minimum of the gradient q : -6.7333225e-05
# Maximum of the gradient q : 4.041309
# Mean of the gradient q : 9.766838e-05

# %%
size = 400
ext = 50
q = 1.

# Create 3D coordinates
x, y, z = np.meshgrid(np.linspace(-ext, ext, size),
                    np.linspace(-ext, ext, size),
                    np.linspace(-ext, ext, size), indexing = 'ij')
x = x.flatten()
y = y.flatten()
z = z.flatten()


list_args = [5]
gradient_02 = gradient_rho(x,y,z,e,p,q,rho0,s,a,b,list_args)

gradqq = gradient_02[:,:,:,0]
gradqq = np.sum(gradqq, axis=2)

mini = np.min(gradqq)
maxi = np.max(gradqq)
mean = np.mean(gradqq)



print("For N = "+str(size)+" , extent = "+str(-ext)+" - "+str(ext)+" , q = "+str(q)+" :")
print("Minimum of the gradient q : "+str(mini))
print("Maximum of the gradient q : "+str(maxi))
print("Mean of the gradient q : "+str(mean)+"\n")
# Out:
# For N = 400 , extent = -50 - 50 , q = 1.0 :
# Minimum of the gradient q : -6.7333225e-05
# Maximum of the gradient q : 4.041309
# Mean of the gradient q : 9.766838e-05

# %%
list_args = [5]
gradient_02 = gradient_rho(0,0,0,e,p,q,rho0,s,a,b,list_args)

# %%
gradient_02
# Out:
# (Array(nan, dtype=float32, weak_type=True),)
